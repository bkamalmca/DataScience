# %%
#Please execute this notebook on the course python environment
#This installs all the pre-requisities for the course

# !pip install tensorflow
# !pip install torch
# !pip install keras
# !pip install transformers
# !pip install datasets
# !pip install sentencepiece
# !pip install evaluate
# !pip install nltk
# !pip install rouge_score
# Out:
# Requirement already satisfied: tensorflow in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.30.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.51.3)
# Requirement already satisfied: numpy>=1.20 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.24.2)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (22.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (15.0.6.1)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (65.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (23.1.21)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.4.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.14.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.28.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.2.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.16.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (6.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)
# Requirement already satisfied: torch in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (1.13.1)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from torch) (4.4.0)
# Requirement already satisfied: keras in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (2.11.0)
# Requirement already satisfied: transformers in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (4.26.1)
# Requirement already satisfied: tqdm>=4.27 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from transformers) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from transformers) (0.13.2)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from transformers) (2022.10.31)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from transformers) (1.24.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from transformers) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from transformers) (22.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from transformers) (2.28.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from requests->transformers) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: datasets in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (2.10.0)
# Requirement already satisfied: xxhash in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from datasets) (3.2.0)
# Requirement already satisfied: requests>=2.19.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from datasets) (2.28.2)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from datasets) (2023.1.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from datasets) (22.0)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from datasets) (1.24.2)
# Requirement already satisfied: responses<0.19 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from datasets) (0.18.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from datasets) (4.64.1)
# Requirement already satisfied: aiohttp in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from datasets) (3.8.4)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from datasets) (1.5.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from datasets) (6.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from datasets) (0.12.1)
# Requirement already satisfied: multiprocess in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from datasets) (0.70.14)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from datasets) (0.3.6)
# Requirement already satisfied: pyarrow>=6.0.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from datasets) (11.0.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from aiohttp->datasets) (3.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.4.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.9.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from requests>=2.19.0->datasets) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: sentencepiece in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (0.1.97)
# Requirement already satisfied: evaluate in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (0.4.0)
# Requirement already satisfied: xxhash in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from evaluate) (3.2.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from evaluate) (22.0)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from evaluate) (1.5.3)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from evaluate) (1.24.2)
# Requirement already satisfied: requests>=2.19.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from evaluate) (2.28.2)
# Requirement already satisfied: dill in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from evaluate) (0.3.6)
# Requirement already satisfied: datasets>=2.0.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from evaluate) (2.10.0)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from evaluate) (2023.1.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from evaluate) (0.12.1)
# Requirement already satisfied: tqdm>=4.62.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from evaluate) (4.64.1)
# Requirement already satisfied: multiprocess in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from evaluate) (0.70.14)
# Requirement already satisfied: responses<0.19 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: pyarrow>=6.0.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from datasets>=2.0.0->evaluate) (11.0.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: aiohttp in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from datasets>=2.0.0->evaluate) (3.8.4)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from requests>=2.19.0->evaluate) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from requests>=2.19.0->evaluate) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from requests>=2.19.0->evaluate) (3.0.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from tqdm>=4.62.1->evaluate) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from pandas->evaluate) (2022.7.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (22.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Requirement already satisfied: nltk in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (3.8.1)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from nltk) (2022.10.31)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: click in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from nltk) (8.1.3)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: rouge_score in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (0.1.2)
# Requirement already satisfied: six>=1.14.0 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: nltk in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: absl-py in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from rouge_score) (1.24.2)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from nltk->rouge_score) (1.2.0)
# Requirement already satisfied: click in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from nltk->rouge_score) (8.1.3)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from nltk->rouge_score) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from nltk->rouge_score) (2022.10.31)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\nlp-tfm-1\lib\site-packages (from click->nltk->rouge_score) (0.4.6)
